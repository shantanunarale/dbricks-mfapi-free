-- %%
CREATE CATALOG IF NOT EXISTS mfapi_dev;
USE CATALOG mfapi_dev;

-- %%
CREATE SCHEMA IF NOT EXISTS mfapi_dev.`00-landing`;
CREATE SCHEMA IF NOT EXISTS mfapi_dev.`01-bronze`;
CREATE SCHEMA IF NOT EXISTS mfapi_dev.`02-silver`;
CREATE SCHEMA IF NOT EXISTS mfapi_dev.`03-gold`;

-- %%
USE SCHEMA `00-landing`;
CREATE VOLUME IF NOT EXISTS api_response;
